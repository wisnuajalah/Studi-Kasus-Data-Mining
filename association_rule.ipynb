# %% [markdown]
# # Analisis pemilihan ekstrakulikuler di SMA X

# %% [markdown]
# ###### Aturan pemilihan eskul:

# %% [markdown]
# 1. Siswa ataupun siswi wajib mengikuti ekstrakurikuler Pramuka
# 2. Siswa ataupun siswi wajib memilih min 2 ekstrakurikuler (termasuk pramuka) dan max 3 ekstrakurikuler
# 3. Hanya siswa/i kelas 10 dan 11 yang boleh mengikuti kegiatan ekstrakurikuler

# %% [markdown]
# ###### Deskripsi dataset:

# %% [markdown]
# 1. Terdapat 150 data siswa/i yang tercatat dalam pemilihan kegiatan ekstrakurikuler
# 2. Pada analisis ini menggunakan library apyori untuk menghitung aturan asosiasi menggunakan metode Apriori

# %%
#menambahkan library apyori
# %pip install apyori
# Out:
# Requirement already satisfied: apyori in c:\programdata\anaconda3\lib\site-packages (1.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import the Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from apyori import apriori

# %% [markdown]
# ### Read data and Display

# %%
data = pd.read_excel("data_eskul.xlsx", header=None)
data
# Out:
#       0                      1         2             3        4         5   \
# 0     No                   Nama     Kelas  JenisKelamin  Pramuka  Paskibra
# 1      1            ADI MULYANA  10 IPA 1             L  Pramuka  Paskibra
# 2      2           ADIK NUGROHO  10 IPA 1             L  Pramuka       NaN
# 3      3  AFRILIA ANGGI SAPUTRI  10 IPA 1             P  Pramuka       NaN
# 4      4        ALVINDI FAUZIAH  10 IPA 1             P  Pramuka       NaN
# ..   ...                    ...       ...           ...      ...       ...
# 146  146         NOLA AFITRIANI  11 IPS 2             P  Pramuka       NaN
# 147  147               NUROHMAN  11 IPS 2             L  Pramuka       NaN
# 148  148         RIZAL SETIAWAN  11 IPS 2             L  Pramuka       NaN
# 149  149        RIZKY ARIL GIAN  11 IPS 2             L  Pramuka       NaN
# 150  150         SITI ROHMAWATI  11 IPS 2             P  Pramuka       NaN
#
#       6    7           8          9     10
# 0    PMR  KIR  VolleyBall  SepakBola  Seni
# 1    NaN  NaN         NaN        NaN   NaN
# 2    NaN  NaN         NaN        NaN   NaN
# 3    NaN  NaN         NaN        NaN   NaN
# 4    PMR  NaN         NaN        NaN   NaN
# ..   ...  ...         ...        ...   ...
# 146  PMR  NaN         NaN        NaN   NaN
# 147  NaN  KIR         NaN        NaN   NaN
# 148  NaN  NaN  VolleyBall        NaN   NaN
# 149  NaN  NaN         NaN  SepakBola   NaN
# 150  PMR  NaN         NaN        NaN  Seni
#
# [151 rows x 11 columns]

# %% [markdown]
# ### Preprocessing on Data

# %% [markdown]
# Disini kita membutuhkan data berupa list untuk Algoritma Apriori.

# %%
records = []
for i in range(1, 150): #mengambil data siswa/i dari data ke-1 sampai dengan 150
    records.append([str(data.values[i, j]) for j in range(2, 10)]) #dengan variabel kelas, jenis kelamin, dan eskul
    
print(type(records))
# Out:
# <class 'list'>

# %% [markdown]
# ### Apriori Algorithm

# %% [markdown]
# 1. Menerapkan algoritma apriori pada data.
# 2. Kami telah menyediakan min_support, min_confidence, min_lift, dan min_length dari sampel-set untuk menemukan aturan.

# %%
association_rules = apriori(records, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
association_results = list(association_rules)

# %%
print("Ada {} relasi yang didapatkan.".format(len(association_results)))
# Out:
# Ada 256 relasi yang didapatkan.

# %%
for i in range(0, len(association_results)):
    print(association_results[i][0])
# Out:
# frozenset({'11 IPS 2', 'VolleyBall'})
# frozenset({'KIR', '10 IPA 1', 'Paskibra'})
# frozenset({'10 IPA 2', 'KIR', 'VolleyBall'})
# frozenset({'10 IPA 3', 'PMR', 'VolleyBall'})
# frozenset({'P', 'KIR', '10 IPA 4'})
# frozenset({'10 IPA 4', 'L', 'SepakBola'})
# frozenset({'10 IPA 4', 'L', 'VolleyBall'})
# frozenset({'P', 'PMR', '10 IPA 4'})
# frozenset({'10 IPA 4', 'VolleyBall', 'SepakBola'})
# frozenset({'KIR', 'VolleyBall', '10 IPA 5'})
# frozenset({'P', 'SepakBola', '10 IPA 5'})
# frozenset({'P', 'VolleyBall', '10 IPA 5'})
# frozenset({'10 IPA 6', 'L', 'SepakBola'})
# frozenset({'PMR', '10 IPA 6', 'SepakBola'})
# frozenset({'10 IPA 7', 'PMR', 'SepakBola'})
# frozenset({'KIR', '10 IPS 1', 'VolleyBall'})
# frozenset({'P', '10 IPS 1', 'PMR'})
# frozenset({'10 IPS 1', 'PMR', 'VolleyBall'})
# frozenset({'KIR', '10 IPS 2', 'PMR'})
# frozenset({'Paskibra', '10 IPS 2', 'SepakBola'})
# frozenset({'Paskibra', '11 IPA 1', 'VolleyBall'})
# frozenset({'11 IPA 1', 'VolleyBall', 'SepakBola'})
# frozenset({'KIR', 'PMR', '11 IPA 2'})
# frozenset({'Paskibra', '11 IPA 2', 'L'})
# frozenset({'11 IPA 2', 'L', 'VolleyBall'})
# frozenset({'Paskibra', '11 IPA 2', 'VolleyBall'})
# frozenset({'11 IPA 2', 'VolleyBall', 'SepakBola'})
# frozenset({'KIR', '11 IPA 3', 'Paskibra'})
# frozenset({'Paskibra', 'L', '11 IPA 3'})
# frozenset({'P', 'Paskibra', '11 IPA 3'})
# frozenset({'KIR', 'L', '11 IPA 5'})
# frozenset({'L', 'SepakBola', '11 IPA 5'})
# frozenset({'P', 'KIR', '11 IPA 6'})
# frozenset({'P', 'SepakBola', '11 IPA 6'})
# frozenset({'L', '11 IPS 2', 'VolleyBall'})
# frozenset({'P', 'PMR', '11 IPS 2'})
# frozenset({'11 IPS 2', 'Pramuka', 'VolleyBall'})
# frozenset({'11 IPS 2', 'nan', 'VolleyBall'})
# frozenset({'KIR', '10 IPA 1', 'L', 'Paskibra'})
# frozenset({'KIR', '10 IPA 1', 'Paskibra', 'Pramuka'})
# frozenset({'KIR', '10 IPA 1', 'Paskibra', 'nan'})
# frozenset({'10 IPA 2', 'KIR', 'VolleyBall', 'P'})
# frozenset({'10 IPA 2', 'KIR', 'VolleyBall', 'Pramuka'})
# frozenset({'10 IPA 2', 'KIR', 'VolleyBall', 'nan'})
# frozenset({'10 IPA 2', 'Paskibra', 'L', 'SepakBola'})
# frozenset({'10 IPA 3', 'PMR', 'L', 'VolleyBall'})
# frozenset({'10 IPA 3', 'Paskibra', 'L', 'SepakBola'})
# frozenset({'10 IPA 3', 'L', 'VolleyBall', 'SepakBola'})
# frozenset({'10 IPA 3', 'PMR', 'VolleyBall', 'Pramuka'})
# frozenset({'10 IPA 3', 'PMR', 'VolleyBall', 'nan'})
# frozenset({'P', 'KIR', 'PMR', '10 IPA 4'})
# frozenset({'P', 'KIR', '10 IPA 4', 'Pramuka'})
# frozenset({'P', 'KIR', '10 IPA 4', 'nan'})
# frozenset({'10 IPA 4', 'L', 'Pramuka', 'SepakBola'})
# frozenset({'10 IPA 4', 'L', 'Pramuka', 'VolleyBall'})
# frozenset({'10 IPA 4', 'L', 'SepakBola', 'VolleyBall'})
# frozenset({'10 IPA 4', 'L', 'nan', 'SepakBola'})
# frozenset({'10 IPA 4', 'L', 'nan', 'VolleyBall'})
# frozenset({'P', 'PMR', '10 IPA 4', 'Pramuka'})
# frozenset({'P', 'PMR', '10 IPA 4', 'nan'})
# frozenset({'10 IPA 4', 'VolleyBall', 'Pramuka', 'SepakBola'})
# frozenset({'10 IPA 4', 'VolleyBall', 'nan', 'SepakBola'})
# frozenset({'KIR', 'L', 'VolleyBall', '10 IPA 5'})
# frozenset({'P', 'KIR', 'VolleyBall', '10 IPA 5'})
# frozenset({'Pramuka', 'KIR', 'VolleyBall', '10 IPA 5'})
# frozenset({'KIR', 'VolleyBall', '10 IPA 5', 'nan'})
# frozenset({'Paskibra', 'L', '10 IPA 5', 'SepakBola'})
# frozenset({'P', 'Pramuka', 'SepakBola', '10 IPA 5'})
# frozenset({'P', 'Pramuka', 'VolleyBall', '10 IPA 5'})
# frozenset({'P', 'SepakBola', 'VolleyBall', '10 IPA 5'})
# frozenset({'P', 'SepakBola', 'nan', '10 IPA 5'})
# frozenset({'P', 'VolleyBall', '10 IPA 5', 'nan'})
# frozenset({'PMR', '10 IPA 6', 'L', 'SepakBola'})
# frozenset({'Paskibra', '10 IPA 6', 'L', 'SepakBola'})
# frozenset({'10 IPA 6', 'L', 'Pramuka', 'SepakBola'})
# frozenset({'10 IPA 6', 'L', 'nan', 'SepakBola'})
# frozenset({'PMR', '10 IPA 6', 'Pramuka', 'SepakBola'})
# frozenset({'PMR', '10 IPA 6', 'nan', 'SepakBola'})
# frozenset({'10 IPA 7', 'PMR', 'L', 'SepakBola'})
# frozenset({'10 IPA 7', 'PMR', 'SepakBola', 'Pramuka'})
# frozenset({'10 IPA 7', 'PMR', 'SepakBola', 'nan'})
# frozenset({'KIR', '10 IPS 1', 'PMR', 'L'})
# frozenset({'KIR', '10 IPS 1', 'VolleyBall', 'P'})
# frozenset({'KIR', '10 IPS 1', 'VolleyBall', 'Pramuka'})
# frozenset({'KIR', '10 IPS 1', 'VolleyBall', 'nan'})
# frozenset({'10 IPS 1', 'L', 'Paskibra', 'SepakBola'})
# frozenset({'P', '10 IPS 1', 'PMR', 'Pramuka'})
# frozenset({'P', '10 IPS 1', 'PMR', 'VolleyBall'})
# frozenset({'P', '10 IPS 1', 'PMR', 'nan'})
# frozenset({'10 IPS 1', 'PMR', 'VolleyBall', 'Pramuka'})
# frozenset({'10 IPS 1', 'PMR', 'VolleyBall', 'nan'})
# frozenset({'KIR', '10 IPS 2', 'L', 'PMR'})
# frozenset({'P', 'KIR', '10 IPS 2', 'PMR'})
# frozenset({'KIR', '10 IPS 2', 'Pramuka', 'PMR'})
# frozenset({'KIR', '10 IPS 2', 'nan', 'PMR'})
# frozenset({'Paskibra', '10 IPS 2', 'L', 'SepakBola'})
# frozenset({'Paskibra', '10 IPS 2', 'SepakBola', 'Pramuka'})
# frozenset({'Paskibra', '10 IPS 2', 'SepakBola', 'nan'})
# frozenset({'11 IPA 1', 'L', 'SepakBola', 'VolleyBall'})
# frozenset({'P', 'Paskibra', '11 IPA 1', 'VolleyBall'})
# frozenset({'Paskibra', '11 IPA 1', 'VolleyBall', 'Pramuka'})
# frozenset({'Paskibra', '11 IPA 1', 'VolleyBall', 'nan'})
# frozenset({'11 IPA 1', 'VolleyBall', 'Pramuka', 'SepakBola'})
# frozenset({'11 IPA 1', 'VolleyBall', 'nan', 'SepakBola'})
# frozenset({'P', 'KIR', 'PMR', '11 IPA 2'})
# frozenset({'KIR', 'PMR', '11 IPA 2', 'Pramuka'})
# frozenset({'KIR', 'PMR', '11 IPA 2', 'nan'})
# frozenset({'Paskibra', '11 IPA 2', 'L', 'Pramuka'})
# frozenset({'Paskibra', '11 IPA 2', 'L', 'VolleyBall'})
# frozenset({'Paskibra', '11 IPA 2', 'L', 'nan'})
# frozenset({'11 IPA 2', 'L', 'Pramuka', 'VolleyBall'})
# frozenset({'11 IPA 2', 'L', 'SepakBola', 'VolleyBall'})
# frozenset({'11 IPA 2', 'L', 'nan', 'VolleyBall'})
# frozenset({'Paskibra', '11 IPA 2', 'VolleyBall', 'Pramuka'})
# frozenset({'Paskibra', '11 IPA 2', 'VolleyBall', 'nan'})
# frozenset({'11 IPA 2', 'VolleyBall', 'Pramuka', 'SepakBola'})
# frozenset({'11 IPA 2', 'VolleyBall', 'nan', 'SepakBola'})
# frozenset({'P', 'KIR', '11 IPA 3', 'Paskibra'})
# frozenset({'KIR', '11 IPA 3', 'Pramuka', 'Paskibra'})
# frozenset({'KIR', '11 IPA 3', 'nan', 'Paskibra'})
# frozenset({'Paskibra', 'L', '11 IPA 3', 'Pramuka'})
# frozenset({'Paskibra', 'L', '11 IPA 3', 'nan'})
# frozenset({'P', 'Paskibra', '11 IPA 3', 'Pramuka'})
# frozenset({'P', 'Paskibra', '11 IPA 3', 'nan'})
# frozenset({'KIR', 'L', 'Pramuka', '11 IPA 5'})
# frozenset({'KIR', 'L', 'nan', '11 IPA 5'})
# frozenset({'L', 'Pramuka', 'SepakBola', '11 IPA 5'})
# frozenset({'L', 'nan', 'SepakBola', '11 IPA 5'})
# frozenset({'P', 'KIR', 'Pramuka', '11 IPA 6'})
# frozenset({'P', 'KIR', 'nan', '11 IPA 6'})
# frozenset({'P', 'SepakBola', 'Pramuka', '11 IPA 6'})
# frozenset({'P', 'SepakBola', 'nan', '11 IPA 6'})
# frozenset({'L', '11 IPS 2', 'Pramuka', 'VolleyBall'})
# frozenset({'L', '11 IPS 2', 'nan', 'VolleyBall'})
# frozenset({'P', 'PMR', '11 IPS 2', 'Pramuka'})
# frozenset({'P', 'PMR', '11 IPS 2', 'nan'})
# frozenset({'11 IPS 2', 'Pramuka', 'nan', 'VolleyBall'})
# frozenset({'KIR', 'L', 'Pramuka', '10 IPA 1', 'Paskibra'})
# frozenset({'KIR', 'L', 'nan', '10 IPA 1', 'Paskibra'})
# frozenset({'KIR', 'nan', 'Pramuka', '10 IPA 1', 'Paskibra'})
# frozenset({'KIR', 'P', 'Pramuka', 'VolleyBall', '10 IPA 2'})
# frozenset({'KIR', 'P', 'nan', 'VolleyBall', '10 IPA 2'})
# frozenset({'KIR', 'nan', 'Pramuka', 'VolleyBall', '10 IPA 2'})
# frozenset({'L', 'SepakBola', 'Pramuka', 'Paskibra', '10 IPA 2'})
# frozenset({'L', 'nan', 'SepakBola', 'Paskibra', '10 IPA 2'})
# frozenset({'10 IPA 3', 'L', 'Pramuka', 'VolleyBall', 'PMR'})
# frozenset({'10 IPA 3', 'L', 'nan', 'VolleyBall', 'PMR'})
# frozenset({'10 IPA 3', 'L', 'SepakBola', 'Pramuka', 'Paskibra'})
# frozenset({'10 IPA 3', 'L', 'nan', 'SepakBola', 'Paskibra'})
# frozenset({'10 IPA 3', 'L', 'SepakBola', 'Pramuka', 'VolleyBall'})
# frozenset({'10 IPA 3', 'L', 'nan', 'SepakBola', 'VolleyBall'})
# frozenset({'10 IPA 3', 'nan', 'Pramuka', 'VolleyBall', 'PMR'})
# frozenset({'KIR', 'P', '10 IPA 4', 'Pramuka', 'PMR'})
# frozenset({'KIR', 'P', '10 IPA 4', 'nan', 'PMR'})
# frozenset({'KIR', 'P', '10 IPA 4', 'nan', 'Pramuka'})
# frozenset({'10 IPA 4', 'L', 'Pramuka', 'SepakBola', 'VolleyBall'})
# frozenset({'10 IPA 4', 'L', 'Pramuka', 'SepakBola', 'nan'})
# frozenset({'10 IPA 4', 'L', 'Pramuka', 'nan', 'VolleyBall'})
# frozenset({'10 IPA 4', 'L', 'nan', 'SepakBola', 'VolleyBall'})
# frozenset({'P', '10 IPA 4', 'nan', 'Pramuka', 'PMR'})
# frozenset({'10 IPA 4', 'SepakBola', 'Pramuka', 'nan', 'VolleyBall'})
# frozenset({'KIR', 'L', 'Pramuka', '10 IPA 5', 'VolleyBall'})
# frozenset({'KIR', 'L', 'nan', '10 IPA 5', 'VolleyBall'})
# frozenset({'KIR', 'P', 'Pramuka', '10 IPA 5', 'VolleyBall'})
# frozenset({'KIR', 'P', 'nan', '10 IPA 5', 'VolleyBall'})
# frozenset({'KIR', 'nan', 'Pramuka', '10 IPA 5', 'VolleyBall'})
# frozenset({'L', 'SepakBola', 'Pramuka', '10 IPA 5', 'Paskibra'})
# frozenset({'L', 'nan', '10 IPA 5', 'SepakBola', 'Paskibra'})
# frozenset({'P', 'SepakBola', 'Pramuka', '10 IPA 5', 'VolleyBall'})
# frozenset({'P', 'SepakBola', 'nan', 'Pramuka', '10 IPA 5'})
# frozenset({'P', 'nan', 'Pramuka', '10 IPA 5', 'VolleyBall'})
# frozenset({'P', 'SepakBola', 'nan', '10 IPA 5', 'VolleyBall'})
# frozenset({'L', 'SepakBola', 'Pramuka', 'PMR', '10 IPA 6'})
# frozenset({'L', 'nan', 'SepakBola', 'PMR', '10 IPA 6'})
# frozenset({'L', 'SepakBola', 'Pramuka', 'Paskibra', '10 IPA 6'})
# frozenset({'L', 'nan', 'SepakBola', 'Paskibra', '10 IPA 6'})
# frozenset({'L', 'SepakBola', 'Pramuka', 'nan', '10 IPA 6'})
# frozenset({'SepakBola', 'nan', 'Pramuka', 'PMR', '10 IPA 6'})
# frozenset({'10 IPA 7', 'L', 'SepakBola', 'Pramuka', 'PMR'})
# frozenset({'10 IPA 7', 'L', 'nan', 'SepakBola', 'PMR'})
# frozenset({'10 IPA 7', 'SepakBola', 'nan', 'Pramuka', 'PMR'})
# frozenset({'KIR', '10 IPS 1', 'L', 'Pramuka', 'PMR'})
# frozenset({'KIR', '10 IPS 1', 'L', 'nan', 'PMR'})
# frozenset({'KIR', 'P', '10 IPS 1', 'Pramuka', 'VolleyBall'})
# frozenset({'KIR', 'P', '10 IPS 1', 'nan', 'VolleyBall'})
# frozenset({'KIR', '10 IPS 1', 'nan', 'Pramuka', 'VolleyBall'})
# frozenset({'10 IPS 1', 'L', 'SepakBola', 'Pramuka', 'Paskibra'})
# frozenset({'10 IPS 1', 'L', 'nan', 'SepakBola', 'Paskibra'})
# frozenset({'P', '10 IPS 1', 'Pramuka', 'VolleyBall', 'PMR'})
# frozenset({'P', '10 IPS 1', 'nan', 'Pramuka', 'PMR'})
# frozenset({'P', '10 IPS 1', 'nan', 'VolleyBall', 'PMR'})
# frozenset({'10 IPS 1', 'nan', 'Pramuka', 'VolleyBall', 'PMR'})
# frozenset({'KIR', '10 IPS 2', 'L', 'Pramuka', 'PMR'})
# frozenset({'KIR', '10 IPS 2', 'L', 'nan', 'PMR'})
# frozenset({'KIR', 'P', '10 IPS 2', 'Pramuka', 'PMR'})
# frozenset({'KIR', 'P', '10 IPS 2', 'nan', 'PMR'})
# frozenset({'KIR', '10 IPS 2', 'nan', 'Pramuka', 'PMR'})
# frozenset({'10 IPS 2', 'L', 'SepakBola', 'Pramuka', 'Paskibra'})
# frozenset({'10 IPS 2', 'L', 'nan', 'SepakBola', 'Paskibra'})
# frozenset({'10 IPS 2', 'SepakBola', 'nan', 'Pramuka', 'Paskibra'})
# frozenset({'11 IPA 1', 'L', 'Pramuka', 'SepakBola', 'VolleyBall'})
# frozenset({'11 IPA 1', 'L', 'nan', 'SepakBola', 'VolleyBall'})
# frozenset({'P', '11 IPA 1', 'Pramuka', 'Paskibra', 'VolleyBall'})
# frozenset({'P', '11 IPA 1', 'nan', 'Paskibra', 'VolleyBall'})
# frozenset({'11 IPA 1', 'nan', 'Pramuka', 'Paskibra', 'VolleyBall'})
# frozenset({'11 IPA 1', 'SepakBola', 'Pramuka', 'nan', 'VolleyBall'})
# frozenset({'KIR', 'P', 'Pramuka', 'PMR', '11 IPA 2'})
# frozenset({'KIR', 'P', 'nan', 'PMR', '11 IPA 2'})
# frozenset({'KIR', 'nan', 'Pramuka', 'PMR', '11 IPA 2'})
# frozenset({'L', 'Pramuka', 'Paskibra', 'VolleyBall', '11 IPA 2'})
# frozenset({'L', 'nan', 'Pramuka', 'Paskibra', '11 IPA 2'})
# frozenset({'L', 'nan', 'Paskibra', 'VolleyBall', '11 IPA 2'})
# frozenset({'L', 'SepakBola', 'Pramuka', 'VolleyBall', '11 IPA 2'})
# frozenset({'L', 'nan', 'Pramuka', 'VolleyBall', '11 IPA 2'})
# frozenset({'L', 'nan', 'SepakBola', 'VolleyBall', '11 IPA 2'})
# frozenset({'nan', 'Pramuka', 'Paskibra', 'VolleyBall', '11 IPA 2'})
# frozenset({'SepakBola', 'nan', 'Pramuka', 'VolleyBall', '11 IPA 2'})
# frozenset({'KIR', 'P', 'Pramuka', 'Paskibra', '11 IPA 3'})
# frozenset({'KIR', 'P', 'nan', 'Paskibra', '11 IPA 3'})
# frozenset({'KIR', 'nan', 'Pramuka', 'Paskibra', '11 IPA 3'})
# frozenset({'L', 'nan', 'Pramuka', 'Paskibra', '11 IPA 3'})
# frozenset({'P', 'nan', 'Pramuka', 'Paskibra', '11 IPA 3'})
# frozenset({'KIR', 'L', 'nan', 'Pramuka', '11 IPA 5'})
# frozenset({'L', 'nan', 'Pramuka', 'SepakBola', '11 IPA 5'})
# frozenset({'KIR', 'P', 'nan', 'Pramuka', '11 IPA 6'})
# frozenset({'P', 'SepakBola', 'nan', 'Pramuka', '11 IPA 6'})
# frozenset({'L', 'nan', 'Pramuka', '11 IPS 2', 'VolleyBall'})
# frozenset({'P', 'nan', 'Pramuka', '11 IPS 2', 'PMR'})
# frozenset({'KIR', 'L', 'nan', 'Pramuka', '10 IPA 1', 'Paskibra'})
# frozenset({'KIR', 'P', 'nan', 'Pramuka', 'VolleyBall', '10 IPA 2'})
# frozenset({'L', 'SepakBola', 'Pramuka', 'nan', 'Paskibra', '10 IPA 2'})
# frozenset({'10 IPA 3', 'L', 'nan', 'Pramuka', 'VolleyBall', 'PMR'})
# frozenset({'10 IPA 3', 'L', 'SepakBola', 'Pramuka', 'nan', 'Paskibra'})
# frozenset({'10 IPA 3', 'L', 'SepakBola', 'Pramuka', 'nan', 'VolleyBall'})
# frozenset({'KIR', 'P', '10 IPA 4', 'nan', 'Pramuka', 'PMR'})
# frozenset({'10 IPA 4', 'L', 'Pramuka', 'SepakBola', 'nan', 'VolleyBall'})
# frozenset({'KIR', 'L', 'nan', 'Pramuka', '10 IPA 5', 'VolleyBall'})
# frozenset({'KIR', 'P', 'nan', 'Pramuka', '10 IPA 5', 'VolleyBall'})
# frozenset({'L', 'SepakBola', 'Pramuka', '10 IPA 5', 'nan', 'Paskibra'})
# frozenset({'P', 'SepakBola', 'nan', 'Pramuka', '10 IPA 5', 'VolleyBall'})
# frozenset({'L', 'SepakBola', 'Pramuka', 'nan', 'PMR', '10 IPA 6'})
# frozenset({'L', 'SepakBola', 'Pramuka', 'nan', 'Paskibra', '10 IPA 6'})
# frozenset({'10 IPA 7', 'L', 'SepakBola', 'Pramuka', 'nan', 'PMR'})
# frozenset({'KIR', '10 IPS 1', 'L', 'nan', 'Pramuka', 'PMR'})
# frozenset({'KIR', 'P', '10 IPS 1', 'nan', 'Pramuka', 'VolleyBall'})
# frozenset({'10 IPS 1', 'L', 'SepakBola', 'Pramuka', 'nan', 'Paskibra'})
# frozenset({'P', '10 IPS 1', 'nan', 'Pramuka', 'VolleyBall', 'PMR'})
# frozenset({'KIR', '10 IPS 2', 'L', 'nan', 'Pramuka', 'PMR'})
# frozenset({'KIR', 'P', '10 IPS 2', 'nan', 'Pramuka', 'PMR'})
# frozenset({'10 IPS 2', 'L', 'SepakBola', 'Pramuka', 'nan', 'Paskibra'})
# frozenset({'11 IPA 1', 'L', 'Pramuka', 'SepakBola', 'nan', 'VolleyBall'})
# frozenset({'P', '11 IPA 1', 'nan', 'Pramuka', 'Paskibra', 'VolleyBall'})
# frozenset({'KIR', 'P', 'nan', 'Pramuka', 'PMR', '11 IPA 2'})
# frozenset({'L', 'nan', 'Pramuka', 'Paskibra', 'VolleyBall', '11 IPA 2'})
# frozenset({'L', 'SepakBola', 'Pramuka', 'nan', 'VolleyBall', '11 IPA 2'})
# frozenset({'KIR', 'P', 'nan', 'Pramuka', 'Paskibra', '11 IPA 3'})

# %%
for item in association_results:
    #index pertama dari daftar dalam yang berisi item dasar dan item yang ditambahkan
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    #index kedua dari daftar list
    print("Support: " + str(item[1]))

    #indeks ketiga dari daftar yang terletak di 0
    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: 11 IPS 2 -> VolleyBall
# Support: 0.026845637583892617
# Confidence: 0.5714285714285714
# Lift: 3.2747252747252746
# =====================================
# Rule: KIR -> 10 IPA 1
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 4.65625
# =====================================
# Rule: 10 IPA 2 -> KIR
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 4.257142857142857
# =====================================
# Rule: 10 IPA 3 -> PMR
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 6.208333333333334
# =====================================
# Rule: P -> KIR
# Support: 0.026845637583892617
# Confidence: 0.5714285714285714
# Lift: 3.87012987012987
# =====================================
# Rule: 10 IPA 4 -> L
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.96
# =====================================
# Rule: 10 IPA 4 -> L
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.730769230769231
# =====================================
# Rule: P -> PMR
# Support: 0.020134228187919462
# Confidence: 0.42857142857142855
# Lift: 3.756302521008403
# =====================================
# Rule: 10 IPA 4 -> VolleyBall
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.730769230769231
# =====================================
# Rule: KIR -> VolleyBall
# Support: 0.013422818791946308
# Confidence: 0.2222222222222222
# Lift: 8.277777777777777
# =====================================
# Rule: P -> SepakBola
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 8.277777777777777
# =====================================
# Rule: P -> VolleyBall
# Support: 0.020134228187919462
# Confidence: 0.3333333333333333
# Lift: 3.8205128205128203
# =====================================
# Rule: 10 IPA 6 -> L
# Support: 0.020134228187919462
# Confidence: 0.75
# Lift: 4.47
# =====================================
# Rule: PMR -> 10 IPA 6
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 6.7727272727272725
# =====================================
# Rule: 10 IPA 7 -> PMR
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.321428571428571
# =====================================
# Rule: KIR -> 10 IPS 1
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 3.3863636363636362
# =====================================
# Rule: P -> 10 IPS 1
# Support: 0.020134228187919462
# Confidence: 0.6
# Lift: 3.1928571428571426
# =====================================
# Rule: 10 IPS 1 -> PMR
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 6.7727272727272725
# =====================================
# Rule: KIR -> 10 IPS 2
# Support: 0.013422818791946308
# Confidence: 0.6666666666666667
# Lift: 3.547619047619048
# =====================================
# Rule: Paskibra -> 10 IPS 2
# Support: 0.013422818791946308
# Confidence: 0.6666666666666667
# Lift: 3.9733333333333336
# =====================================
# Rule: Paskibra -> 11 IPA 1
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 6.208333333333334
# =====================================
# Rule: 11 IPA 1 -> VolleyBall
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.730769230769231
# =====================================
# Rule: KIR -> PMR
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 4.257142857142857
# =====================================
# Rule: Paskibra -> 11 IPA 2
# Support: 0.013422818791946308
# Confidence: 0.6666666666666667
# Lift: 3.104166666666667
# =====================================
# Rule: 11 IPA 2 -> L
# Support: 0.013422818791946308
# Confidence: 0.33333333333333337
# Lift: 3.820512820512821
# =====================================
# Rule: Paskibra -> 11 IPA 2
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 12.416666666666668
# =====================================
# Rule: 11 IPA 2 -> VolleyBall
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.730769230769231
# =====================================
# Rule: KIR -> 11 IPA 3
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 18.625
# =====================================
# Rule: Paskibra -> L
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 4.65625
# =====================================
# Rule: P -> Paskibra
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 3.104166666666667
# =====================================
# Rule: KIR -> L
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 5.730769230769231
# =====================================
# Rule: L -> SepakBola
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 3.239130434782609
# =====================================
# Rule: P -> KIR
# Support: 0.020134228187919462
# Confidence: 0.5
# Lift: 3.3863636363636362
# =====================================
# Rule: P -> SepakBola
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 12.416666666666668
# =====================================
# Rule: L -> 11 IPS 2
# Support: 0.026845637583892617
# Confidence: 0.5714285714285714
# Lift: 6.549450549450549
# =====================================
# Rule: P -> PMR
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.321428571428571
# =====================================
# Rule: 11 IPS 2 -> Pramuka
# Support: 0.026845637583892617
# Confidence: 0.5714285714285714
# Lift: 3.2747252747252746
# =====================================
# Rule: 11 IPS 2 -> nan
# Support: 0.026845637583892617
# Confidence: 0.5714285714285714
# Lift: 3.2747252747252746
# =====================================
# Rule: KIR -> 10 IPA 1
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 7.45
# =====================================
# Rule: KIR -> 10 IPA 1
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 4.65625
# =====================================
# Rule: KIR -> 10 IPA 1
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 4.65625
# =====================================
# Rule: 10 IPA 2 -> KIR
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 5.730769230769231
# =====================================
# Rule: 10 IPA 2 -> KIR
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 4.257142857142857
# =====================================
# Rule: 10 IPA 2 -> KIR
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 4.257142857142857
# =====================================
# Rule: 10 IPA 2 -> Paskibra
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 3.239130434782609
# =====================================
# Rule: 10 IPA 3 -> PMR
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 5.730769230769231
# =====================================
# Rule: 10 IPA 3 -> Paskibra
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 3.239130434782609
# =====================================
# Rule: 10 IPA 3 -> L
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 3.820512820512821
# =====================================
# Rule: 10 IPA 3 -> PMR
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 6.208333333333334
# =====================================
# Rule: 10 IPA 3 -> PMR
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 6.208333333333334
# =====================================
# Rule: P -> KIR
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 7.095238095238096
# =====================================
# Rule: P -> KIR
# Support: 0.026845637583892617
# Confidence: 0.5714285714285714
# Lift: 3.87012987012987
# =====================================
# Rule: P -> KIR
# Support: 0.026845637583892617
# Confidence: 0.5714285714285714
# Lift: 3.87012987012987
# =====================================
# Rule: 10 IPA 4 -> L
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.96
# =====================================
# Rule: 10 IPA 4 -> L
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.730769230769231
# =====================================
# Rule: 10 IPA 4 -> L
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 29.8
# =====================================
# Rule: 10 IPA 4 -> L
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.96
# =====================================
# Rule: 10 IPA 4 -> L
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.730769230769231
# =====================================
# Rule: P -> PMR
# Support: 0.020134228187919462
# Confidence: 0.42857142857142855
# Lift: 3.756302521008403
# =====================================
# Rule: P -> PMR
# Support: 0.020134228187919462
# Confidence: 0.42857142857142855
# Lift: 3.756302521008403
# =====================================
# Rule: 10 IPA 4 -> VolleyBall
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.730769230769231
# =====================================
# Rule: 10 IPA 4 -> VolleyBall
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.730769230769231
# =====================================
# Rule: KIR -> L
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 3.820512820512821
# =====================================
# Rule: P -> KIR
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 3.820512820512821
# =====================================
# Rule: Pramuka -> KIR
# Support: 0.013422818791946308
# Confidence: 0.2222222222222222
# Lift: 8.277777777777777
# =====================================
# Rule: KIR -> VolleyBall
# Support: 0.013422818791946308
# Confidence: 0.2222222222222222
# Lift: 8.277777777777777
# =====================================
# Rule: Paskibra -> L
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 3.725
# =====================================
# Rule: P -> Pramuka
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 8.277777777777777
# =====================================
# Rule: P -> Pramuka
# Support: 0.020134228187919462
# Confidence: 0.3333333333333333
# Lift: 3.8205128205128203
# =====================================
# Rule: P -> SepakBola
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 9.933333333333334
# =====================================
# Rule: P -> SepakBola
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 8.277777777777777
# =====================================
# Rule: P -> VolleyBall
# Support: 0.020134228187919462
# Confidence: 0.3333333333333333
# Lift: 3.8205128205128203
# =====================================
# Rule: PMR -> 10 IPA 6
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 18.625
# =====================================
# Rule: Paskibra -> 10 IPA 6
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 5.321428571428571
# =====================================
# Rule: 10 IPA 6 -> L
# Support: 0.020134228187919462
# Confidence: 0.75
# Lift: 4.47
# =====================================
# Rule: 10 IPA 6 -> L
# Support: 0.020134228187919462
# Confidence: 0.75
# Lift: 4.47
# =====================================
# Rule: PMR -> 10 IPA 6
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 6.7727272727272725
# =====================================
# Rule: PMR -> 10 IPA 6
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 6.7727272727272725
# =====================================
# Rule: 10 IPA 7 -> PMR
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 37.25
# =====================================
# Rule: 10 IPA 7 -> PMR
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.321428571428571
# =====================================
# Rule: 10 IPA 7 -> PMR
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.321428571428571
# =====================================
# Rule: KIR -> 10 IPS 1
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 3.3863636363636362
# =====================================
# Rule: KIR -> 10 IPS 1
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 7.45
# =====================================
# Rule: KIR -> 10 IPS 1
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 3.3863636363636362
# =====================================
# Rule: KIR -> 10 IPS 1
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 3.3863636363636362
# =====================================
# Rule: 10 IPS 1 -> L
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 3.239130434782609
# =====================================
# Rule: P -> 10 IPS 1
# Support: 0.020134228187919462
# Confidence: 0.6
# Lift: 3.1928571428571426
# =====================================
# Rule: P -> 10 IPS 1
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 14.9
# =====================================
# Rule: P -> 10 IPS 1
# Support: 0.020134228187919462
# Confidence: 0.6
# Lift: 3.1928571428571426
# =====================================
# Rule: 10 IPS 1 -> PMR
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 6.7727272727272725
# =====================================
# Rule: 10 IPS 1 -> PMR
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 6.7727272727272725
# =====================================
# Rule: KIR -> 10 IPS 2
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 4.515151515151516
# =====================================
# Rule: P -> KIR
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 3.820512820512821
# =====================================
# Rule: KIR -> 10 IPS 2
# Support: 0.013422818791946308
# Confidence: 0.6666666666666667
# Lift: 3.547619047619048
# =====================================
# Rule: KIR -> 10 IPS 2
# Support: 0.013422818791946308
# Confidence: 0.6666666666666667
# Lift: 3.547619047619048
# =====================================
# Rule: Paskibra -> 10 IPS 2
# Support: 0.013422818791946308
# Confidence: 0.33333333333333337
# Lift: 7.095238095238096
# =====================================
# Rule: Paskibra -> 10 IPS 2
# Support: 0.013422818791946308
# Confidence: 0.6666666666666667
# Lift: 3.9733333333333336
# =====================================
# Rule: Paskibra -> 10 IPS 2
# Support: 0.013422818791946308
# Confidence: 0.6666666666666667
# Lift: 3.9733333333333336
# =====================================
# Rule: 11 IPA 1 -> L
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 7.45
# =====================================
# Rule: P -> Paskibra
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 5.730769230769231
# =====================================
# Rule: Paskibra -> 11 IPA 1
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 6.208333333333334
# =====================================
# Rule: Paskibra -> 11 IPA 1
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 6.208333333333334
# =====================================
# Rule: 11 IPA 1 -> VolleyBall
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.730769230769231
# =====================================
# Rule: 11 IPA 1 -> VolleyBall
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.730769230769231
# =====================================
# Rule: P -> KIR
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 4.38235294117647
# =====================================
# Rule: KIR -> PMR
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 4.257142857142857
# =====================================
# Rule: KIR -> PMR
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 4.257142857142857
# =====================================
# Rule: Paskibra -> 11 IPA 2
# Support: 0.013422818791946308
# Confidence: 0.6666666666666667
# Lift: 3.104166666666667
# =====================================
# Rule: Paskibra -> 11 IPA 2
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 24.833333333333336
# =====================================
# Rule: Paskibra -> 11 IPA 2
# Support: 0.013422818791946308
# Confidence: 0.6666666666666667
# Lift: 3.104166666666667
# =====================================
# Rule: 11 IPA 2 -> L
# Support: 0.013422818791946308
# Confidence: 0.33333333333333337
# Lift: 3.820512820512821
# =====================================
# Rule: 11 IPA 2 -> L
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 9.933333333333334
# =====================================
# Rule: 11 IPA 2 -> L
# Support: 0.013422818791946308
# Confidence: 0.33333333333333337
# Lift: 3.820512820512821
# =====================================
# Rule: Paskibra -> 11 IPA 2
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 12.416666666666668
# =====================================
# Rule: Paskibra -> 11 IPA 2
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 12.416666666666668
# =====================================
# Rule: 11 IPA 2 -> VolleyBall
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.730769230769231
# =====================================
# Rule: 11 IPA 2 -> VolleyBall
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.730769230769231
# =====================================
# Rule: P -> KIR
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 37.25
# =====================================
# Rule: KIR -> 11 IPA 3
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 18.625
# =====================================
# Rule: KIR -> 11 IPA 3
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 18.625
# =====================================
# Rule: Paskibra -> L
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 4.65625
# =====================================
# Rule: Paskibra -> L
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 4.65625
# =====================================
# Rule: P -> Paskibra
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 3.104166666666667
# =====================================
# Rule: P -> Paskibra
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 3.104166666666667
# =====================================
# Rule: KIR -> L
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 5.730769230769231
# =====================================
# Rule: KIR -> L
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 5.730769230769231
# =====================================
# Rule: L -> Pramuka
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 3.239130434782609
# =====================================
# Rule: L -> nan
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 3.239130434782609
# =====================================
# Rule: P -> KIR
# Support: 0.020134228187919462
# Confidence: 0.5
# Lift: 3.3863636363636362
# =====================================
# Rule: P -> KIR
# Support: 0.020134228187919462
# Confidence: 0.5
# Lift: 3.3863636363636362
# =====================================
# Rule: P -> SepakBola
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 12.416666666666668
# =====================================
# Rule: P -> SepakBola
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 12.416666666666668
# =====================================
# Rule: L -> 11 IPS 2
# Support: 0.026845637583892617
# Confidence: 0.5714285714285714
# Lift: 6.549450549450549
# =====================================
# Rule: L -> 11 IPS 2
# Support: 0.026845637583892617
# Confidence: 0.5714285714285714
# Lift: 6.549450549450549
# =====================================
# Rule: P -> PMR
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.321428571428571
# =====================================
# Rule: P -> PMR
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.321428571428571
# =====================================
# Rule: 11 IPS 2 -> Pramuka
# Support: 0.026845637583892617
# Confidence: 0.5714285714285714
# Lift: 3.2747252747252746
# =====================================
# Rule: KIR -> L
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 7.45
# =====================================
# Rule: KIR -> L
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 7.45
# =====================================
# Rule: KIR -> nan
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 4.65625
# =====================================
# Rule: KIR -> P
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 5.730769230769231
# =====================================
# Rule: KIR -> P
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 5.730769230769231
# =====================================
# Rule: KIR -> nan
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 4.257142857142857
# =====================================
# Rule: L -> SepakBola
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 3.239130434782609
# =====================================
# Rule: L -> nan
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 3.239130434782609
# =====================================
# Rule: 10 IPA 3 -> L
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 5.730769230769231
# =====================================
# Rule: 10 IPA 3 -> L
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 5.730769230769231
# =====================================
# Rule: 10 IPA 3 -> L
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 3.239130434782609
# =====================================
# Rule: 10 IPA 3 -> L
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 3.239130434782609
# =====================================
# Rule: 10 IPA 3 -> L
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 3.820512820512821
# =====================================
# Rule: 10 IPA 3 -> L
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 3.820512820512821
# =====================================
# Rule: 10 IPA 3 -> nan
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 6.208333333333334
# =====================================
# Rule: KIR -> P
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 7.095238095238096
# =====================================
# Rule: KIR -> P
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 7.095238095238096
# =====================================
# Rule: KIR -> P
# Support: 0.026845637583892617
# Confidence: 0.5714285714285714
# Lift: 3.87012987012987
# =====================================
# Rule: 10 IPA 4 -> L
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 29.8
# =====================================
# Rule: 10 IPA 4 -> L
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.96
# =====================================
# Rule: 10 IPA 4 -> L
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.730769230769231
# =====================================
# Rule: 10 IPA 4 -> L
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 29.8
# =====================================
# Rule: P -> 10 IPA 4
# Support: 0.020134228187919462
# Confidence: 0.42857142857142855
# Lift: 3.756302521008403
# =====================================
# Rule: 10 IPA 4 -> SepakBola
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.730769230769231
# =====================================
# Rule: KIR -> L
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 3.820512820512821
# =====================================
# Rule: KIR -> L
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 3.820512820512821
# =====================================
# Rule: KIR -> P
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 3.820512820512821
# =====================================
# Rule: KIR -> P
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 3.820512820512821
# =====================================
# Rule: KIR -> nan
# Support: 0.013422818791946308
# Confidence: 0.2222222222222222
# Lift: 8.277777777777777
# =====================================
# Rule: L -> SepakBola
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 3.725
# =====================================
# Rule: L -> nan
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 3.725
# =====================================
# Rule: P -> SepakBola
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 9.933333333333334
# =====================================
# Rule: P -> SepakBola
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 8.277777777777777
# =====================================
# Rule: P -> nan
# Support: 0.020134228187919462
# Confidence: 0.3333333333333333
# Lift: 3.8205128205128203
# =====================================
# Rule: P -> SepakBola
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 9.933333333333334
# =====================================
# Rule: L -> SepakBola
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 18.625
# =====================================
# Rule: L -> nan
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 18.625
# =====================================
# Rule: L -> SepakBola
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 5.321428571428571
# =====================================
# Rule: L -> nan
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 5.321428571428571
# =====================================
# Rule: L -> SepakBola
# Support: 0.020134228187919462
# Confidence: 0.75
# Lift: 4.47
# =====================================
# Rule: SepakBola -> nan
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 6.7727272727272725
# =====================================
# Rule: 10 IPA 7 -> L
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 37.25
# =====================================
# Rule: 10 IPA 7 -> L
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 37.25
# =====================================
# Rule: 10 IPA 7 -> SepakBola
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.321428571428571
# =====================================
# Rule: KIR -> 10 IPS 1
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 3.3863636363636362
# =====================================
# Rule: KIR -> 10 IPS 1
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 3.3863636363636362
# =====================================
# Rule: KIR -> P
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 7.45
# =====================================
# Rule: KIR -> P
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 7.45
# =====================================
# Rule: KIR -> 10 IPS 1
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 3.3863636363636362
# =====================================
# Rule: 10 IPS 1 -> L
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 3.239130434782609
# =====================================
# Rule: 10 IPS 1 -> L
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 3.239130434782609
# =====================================
# Rule: P -> 10 IPS 1
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 14.9
# =====================================
# Rule: P -> 10 IPS 1
# Support: 0.020134228187919462
# Confidence: 0.6
# Lift: 3.1928571428571426
# =====================================
# Rule: P -> 10 IPS 1
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 14.9
# =====================================
# Rule: 10 IPS 1 -> nan
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 6.7727272727272725
# =====================================
# Rule: KIR -> 10 IPS 2
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 4.515151515151516
# =====================================
# Rule: KIR -> 10 IPS 2
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 4.515151515151516
# =====================================
# Rule: KIR -> P
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 3.820512820512821
# =====================================
# Rule: KIR -> P
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 3.820512820512821
# =====================================
# Rule: KIR -> 10 IPS 2
# Support: 0.013422818791946308
# Confidence: 0.6666666666666667
# Lift: 3.547619047619048
# =====================================
# Rule: 10 IPS 2 -> L
# Support: 0.013422818791946308
# Confidence: 0.33333333333333337
# Lift: 7.095238095238096
# =====================================
# Rule: 10 IPS 2 -> L
# Support: 0.013422818791946308
# Confidence: 0.33333333333333337
# Lift: 7.095238095238096
# =====================================
# Rule: 10 IPS 2 -> SepakBola
# Support: 0.013422818791946308
# Confidence: 0.6666666666666667
# Lift: 3.9733333333333336
# =====================================
# Rule: 11 IPA 1 -> L
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 7.45
# =====================================
# Rule: 11 IPA 1 -> L
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 7.45
# =====================================
# Rule: P -> 11 IPA 1
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 5.730769230769231
# =====================================
# Rule: P -> 11 IPA 1
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 5.730769230769231
# =====================================
# Rule: 11 IPA 1 -> nan
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 6.208333333333334
# =====================================
# Rule: 11 IPA 1 -> SepakBola
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.730769230769231
# =====================================
# Rule: KIR -> P
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 4.38235294117647
# =====================================
# Rule: KIR -> P
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 4.38235294117647
# =====================================
# Rule: KIR -> nan
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 4.257142857142857
# =====================================
# Rule: L -> Pramuka
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 24.833333333333336
# =====================================
# Rule: L -> nan
# Support: 0.013422818791946308
# Confidence: 0.6666666666666667
# Lift: 3.104166666666667
# =====================================
# Rule: L -> nan
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 24.833333333333336
# =====================================
# Rule: L -> SepakBola
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 9.933333333333334
# =====================================
# Rule: L -> nan
# Support: 0.013422818791946308
# Confidence: 0.33333333333333337
# Lift: 3.820512820512821
# =====================================
# Rule: L -> nan
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 9.933333333333334
# =====================================
# Rule: nan -> Pramuka
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 12.416666666666668
# =====================================
# Rule: SepakBola -> nan
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.730769230769231
# =====================================
# Rule: KIR -> P
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 37.25
# =====================================
# Rule: KIR -> P
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 37.25
# =====================================
# Rule: KIR -> nan
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 18.625
# =====================================
# Rule: L -> nan
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 4.65625
# =====================================
# Rule: P -> nan
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 3.104166666666667
# =====================================
# Rule: KIR -> L
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 5.730769230769231
# =====================================
# Rule: L -> nan
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 3.239130434782609
# =====================================
# Rule: KIR -> P
# Support: 0.020134228187919462
# Confidence: 0.5
# Lift: 3.3863636363636362
# =====================================
# Rule: P -> SepakBola
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 12.416666666666668
# =====================================
# Rule: L -> nan
# Support: 0.026845637583892617
# Confidence: 0.5714285714285714
# Lift: 6.549450549450549
# =====================================
# Rule: P -> nan
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 5.321428571428571
# =====================================
# Rule: KIR -> L
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 7.45
# =====================================
# Rule: KIR -> P
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 5.730769230769231
# =====================================
# Rule: L -> SepakBola
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 3.239130434782609
# =====================================
# Rule: 10 IPA 3 -> L
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 5.730769230769231
# =====================================
# Rule: 10 IPA 3 -> L
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 3.239130434782609
# =====================================
# Rule: 10 IPA 3 -> L
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 3.820512820512821
# =====================================
# Rule: KIR -> P
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 7.095238095238096
# =====================================
# Rule: 10 IPA 4 -> L
# Support: 0.006711409395973154
# Confidence: 1.0
# Lift: 29.8
# =====================================
# Rule: KIR -> L
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 3.820512820512821
# =====================================
# Rule: KIR -> P
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 3.820512820512821
# =====================================
# Rule: L -> SepakBola
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 3.725
# =====================================
# Rule: P -> SepakBola
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 9.933333333333334
# =====================================
# Rule: L -> SepakBola
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 18.625
# =====================================
# Rule: L -> SepakBola
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 5.321428571428571
# =====================================
# Rule: 10 IPA 7 -> L
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 37.25
# =====================================
# Rule: KIR -> 10 IPS 1
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 3.3863636363636362
# =====================================
# Rule: KIR -> P
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 7.45
# =====================================
# Rule: 10 IPS 1 -> L
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 3.239130434782609
# =====================================
# Rule: P -> 10 IPS 1
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 14.9
# =====================================
# Rule: KIR -> 10 IPS 2
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 4.515151515151516
# =====================================
# Rule: KIR -> P
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 3.820512820512821
# =====================================
# Rule: 10 IPS 2 -> L
# Support: 0.013422818791946308
# Confidence: 0.33333333333333337
# Lift: 7.095238095238096
# =====================================
# Rule: 11 IPA 1 -> L
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 7.45
# =====================================
# Rule: P -> 11 IPA 1
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 5.730769230769231
# =====================================
# Rule: KIR -> P
# Support: 0.006711409395973154
# Confidence: 0.5
# Lift: 4.38235294117647
# =====================================
# Rule: L -> nan
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 24.833333333333336
# =====================================
# Rule: L -> SepakBola
# Support: 0.006711409395973154
# Confidence: 0.33333333333333337
# Lift: 9.933333333333334
# =====================================
# Rule: KIR -> P
# Support: 0.006711409395973154
# Confidence: 0.25
# Lift: 37.25
# =====================================
